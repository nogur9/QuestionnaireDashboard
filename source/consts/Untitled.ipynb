# %%
import os

BASE_DIR = os.path.dirname(os.path.abspath(__file__).parent().parent())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 import os
# ----> 3 BASE_DIR = os.path.dirname(os.path.abspath(__file__).parent().parent())
#
# NameError: name '__file__' is not defined
